# %% [markdown]
# # This is my resource notebook for the Google Data Analytics Certificate
#
# My name is Elmo
#
# Here is a [link to the Kaggle website](https://kaggle.com)
#
# **This is bold text **
#
# *This is italic text*
#
# Three interesting facts about me are:
# * Fact 1
# * Fact 2
# * Fact 3
#
# When I make my favorite meal, the first three steps are:
# 1. Step 1
# 2. Step 2
# 3. Step 3
#
# I'm really inspired by the following quote from C.S. Lewis:
#
# > "You are never too old to set another goal or to dream a new dream"
